# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import cv2

from skimage.feature import hog
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras import layers, models

# Path ke folder images lokal
train_dir = 'images/training'
test_dir = 'images/test'

# %%
# Load images and labels from a directory structure
def load_dataset(img_dir):
    p = Path(img_dir)
    img_list = []
    for folder in p.glob('*'):
        if folder.is_dir():  # Pastikan itu folder
            label = folder.name
            for file in folder.glob('*.jpg'):
                img = cv2.imread(str(file))
                if img is not None:  # Cek apakah gambar berhasil dibaca
                    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                    img_list.append((img, label))
    return img_list

# Ganti path Google Colab dengan path lokal
train_dir = "images/training"  # Path lokal di VS Code
test_dir  = "images/test"      # Path lokal di VS Code

# Load dataset
train_img = load_dataset(train_dir)
test_img  = load_dataset(test_dir)

print(f"Jumlah data training: {len(train_img)}")
print(f"Jumlah data testing: {len(test_img)}")
# Out:
# Jumlah data training: 240
# Jumlah data testing: 160

# %%
# Preprocess images: resize and encode labels
def resize_image(img, size=(256,256)):
    return cv2.resize(img, size)

def label_encoder(label):
    return 1 if label == 'day' else 0

def preprocess(img_list):
    X = []
    y = []
    for img, label in img_list:
        img_std = resize_image(img)
        X.append(img_std)
        y.append(label_encoder(label))
    return X, y

X_train_img, y_train = preprocess(train_img)
X_test_img,  y_test  = preprocess(test_img)

# %%
# Extract HOG features
def extract_hog(X_imgs):
    feats = []
    for img in X_imgs:
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        hog_feat = hog(gray,
                       orientations=9,
                       pixels_per_cell=(8,8),
                       cells_per_block=(2,2),
                       block_norm='L2-Hys',
                       visualize=False,
                       feature_vector=True)
        feats.append(hog_feat)
    return np.array(feats)

X_train_feat = extract_hog(X_train_img)
X_test_feat  = extract_hog(X_test_img)

# %%
# Normalize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_feat)
X_test_scaled  = scaler.transform(X_test_feat)

# %%
# Split training data for validation
X_train, X_val, y_train, y_val = train_test_split(
    X_train_scaled, y_train,
    test_size=0.2,
    random_state=42
)

# %%
# Convert labels to numpy arrays (required for Keras)
y_train = np.array(y_train)
y_val = np.array(y_val)
y_test = np.array(y_test)

# %%
# Build a simple feedforward neural network
# Define model architecture
# input_dim is the number of features in the dataset
# Hidden layer -> 128 neurons, ReLU activation
# Hidden layer -> 64 neurons, ReLU activation
# Output layer -> 1 neuron, Sigmoid activation (for binary classification)
input_dim = X_train.shape[1]

model = models.Sequential([
    layers.Input(shape=(input_dim,)),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │     4,428,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,436,737 (16.92 MB)
#  Trainable params: 4,436,737 (16.92 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=32,
    validation_data=(X_val, y_val)
)
# Out:
# Epoch 1/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - accuracy: 0.7656 - loss: 1.4862 - val_accuracy: 0.9375 - val_loss: 0.2937
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - accuracy: 0.9635 - loss: 0.1470 - val_accuracy: 0.9583 - val_loss: 0.2384
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.9948 - loss: 0.0158 - val_accuracy: 0.9583 - val_loss: 0.2584
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.9948 - loss: 0.0077 - val_accuracy: 0.9583 - val_loss: 0.2781
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 3.9611e-04 - val_accuracy: 0.9375 - val_loss: 0.3082
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 1.0000 - loss: 2.6856e-04 - val_accuracy: 0.9375 - val_loss: 0.3360
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 1.0000 - loss: 7.2112e-05 - val_accuracy: 0.9375 - val_loss: 0.3460
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 4.6392e-05 - val_accuracy: 0.9375 - val_loss: 0.3458
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 2.6439e-05 - val_accuracy: 0.9375 - val_loss: 0.3395
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 1.0000 - loss: 1.5754e-05 - val_accuracy: 0.9375 - val_loss: 0.3321
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 1.0000 - loss: 1.1103e-05 - val_accuracy: 0.9375 - val_loss: 0.3256
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 7.5088e-06 - val_accuracy: 0.9375 - val_loss: 0.3209
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 5.6192e-06 - val_accuracy: 0.9375 - val_loss: 0.3175
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 4.7037e-06 - val_accuracy: 0.9375 - val_loss: 0.3150
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 1.0000 - loss: 3.9240e-06 - val_accuracy: 0.9375 - val_loss: 0.3132
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 1.0000 - loss: 3.7674e-06 - val_accuracy: 0.9375 - val_loss: 0.3114
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 1.0000 - loss: 3.3022e-06 - val_accuracy: 0.9375 - val_loss: 0.3102
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 3.1364e-06 - val_accuracy: 0.9375 - val_loss: 0.3090
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 1.0000 - loss: 3.0105e-06 - val_accuracy: 0.9375 - val_loss: 0.3078
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 1.0000 - loss: 2.7975e-06 - val_accuracy: 0.9375 - val_loss: 0.3067

# %%
# Evaluate the model on test data
test_loss, test_acc = model.evaluate(X_test_scaled, y_test)
print("Akurasi Test:", test_acc)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8500 - loss: 0.8988
# Akurasi Test: 0.8500000238418579

# %%
# Generate classification report and confusion matrix
y_pred_prob = model.predict(X_test_scaled)
y_pred = (y_pred_prob > 0.5).astype(int)

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86        80
#            1       0.88      0.81      0.84        80
#
#     accuracy                           0.85       160
#    macro avg       0.85      0.85      0.85       160
# weighted avg       0.85      0.85      0.85       160
#
# [[71  9]
#  [15 65]]

# %%
# Save the trained model
import pickle

# 1. Simpan Model
# Menggunakan format .h5
model.save('day_night_model.h5')
print("✅ Model berhasil disimpan sebagai: day_night_model.h5")

# 2. Simpan Scaler
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
print("✅ Scaler berhasil disimpan sebagai: scaler.pkl")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Model berhasil disimpan sebagai: day_night_model.h5
# ✅ Scaler berhasil disimpan sebagai: scaler.pkl
